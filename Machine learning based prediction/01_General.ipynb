# %% [markdown]
# ## Data Loading

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Read CSV while excluding the "reference" column
df = pd.read_csv("Dataset.csv")

# Drop the "reference" column if it exists
if "Reference" in df.columns:
    df = df.drop(columns=["Reference"])

# Display the dataframe
print(df.head())
# Out:
#   Dopant    EN    IR  State  NED    FIE  Ratio      MMM   LV   HV  Current  \
# 0     Mo  2.16  70.0      4   42  684.3  0.114  97.8783  1.0  1.8      0.1
# 1     Mo  2.16  70.0      4   42  684.3  0.114  97.8783  1.0  1.8      0.2
# 2     Mo  2.16  70.0      4   42  684.3  0.114  97.8783  1.0  1.8      0.5
# 3     Mo  2.16  70.0      4   42  684.3  0.114  97.8783  1.0  1.8      1.0
# 4     Mo  2.16  70.0      4   42  684.3  0.114  97.8783  1.0  1.8      2.0
#
#     DC
# 0  231
# 1  329
# 2  297
# 3  251
# 4  174

# %%
plt.rcParams.update({'font.size': 10})
# Create histogram
sns.histplot(df, x="Dopant", discrete=True, color="skyblue")

# Labels and title
plt.xlabel("Dopant")
plt.ylabel("Count")
plt.savefig("Histogram_Dopant.tiff", format='tiff', dpi=600, bbox_inches='tight')

# Show plot
plt.show()

# %%
plt.rcParams.update({'font.size': 20})
# Create histogram
sns.histplot(df, x="Current", discrete=True, color="skyblue")

# Labels and title
plt.xlabel("Current")
plt.ylabel("Count")
plt.savefig("Histogram_Current.tiff", format='tiff', dpi=600, bbox_inches='tight')

# Show plot
plt.show()

# %%
plt.rcParams.update({'font.size': 20})

# Create histogram
sns.histplot(df, x="DC", discrete=False, color="skyblue")

# Labels and title
plt.xlabel("DC")
plt.ylabel("Count")
plt.savefig("Histogram_DC.tiff", format='tiff', dpi=600, bbox_inches='tight')

# Show plot
plt.show()

# %%
plt.rcParams.update({'font.size': 20})

# Create histogram
sns.histplot(df, x="LV", discrete=False, color="skyblue")

# Labels and title
plt.xlabel("LV")
plt.ylabel("Count")
plt.savefig("Histogram_LV.tiff", format='tiff', dpi=600, bbox_inches='tight')

# Show plot
plt.show()

# %%
plt.rcParams.update({'font.size': 20})

# Create histogram
sns.histplot(df, x="HV", discrete=False, color="skyblue")

# Labels and title
plt.xlabel("HV")
plt.ylabel("Count")
plt.savefig("Histogram_HV.tiff", format='tiff', dpi=600, bbox_inches='tight')

# Show plot
plt.show()

# %%
plt.rcParams.update({'font.size': 20})

# Create histogram
sns.histplot(df, x="Ratio", discrete=False, color="skyblue")

# Labels and title
plt.xlabel("Ratio")
plt.ylabel("Count")
plt.savefig("Histogram_Ratio.tiff", format='tiff', dpi=600, bbox_inches='tight')

# Show plot
plt.show()

# %% [markdown]
# ## Pearson Correlation

# %%
plt.rcParams.update({'font.size': 12})

# Drop the "Dopant" column if it exists
temp_df = df.drop(columns=["Dopant"])

# Calculate the correlation matrix (Pearson by default)
corr_matrix = temp_df.corr()

# Create a mask for the upper triangle (excluding the diagonal)
mask = np.triu(np.ones_like(corr_matrix, dtype=bool), k=1)  # k=1 excludes the diagonal

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Draw the heatmap with the mask
sns.heatmap(
    corr_matrix, 
    mask=mask, 
    annot=True, 
    cmap='coolwarm', 
    square=True, 
    linewidths=0.5, 
    cbar_kws={"shrink": 0.8},
    annot_kws={"fontsize": 12}
)
plt.savefig("Pearson.tiff", format='tiff', dpi=600, bbox_inches='tight')
plt.show()
